# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaista-sk/Python-mini-projects/blob/main/ATM_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance = 0.0
pin = "1234"  # default PIN

def check_balance():
    print(f"Your current balance is: {balance:.2f}")
def deposit():
    global balance
    try:
        amount = float(input("Enter amount to deposit: "))
        if amount <= 0:
            print("Amount must be positive!")
            return
        balance += amount
        print(f"Deposited {amount:.2f}. New balance: {balance:.2f}")
    except ValueError:
        print("Invalid amount!")
def withdraw():
    global balance
    try:
        amount = float(input("Enter amount to withdraw: "))
        if amount <= 0:
            print("Amount must be positive!")
            return
        if amount > balance:
            print("Insufficient balance!")
            return
        balance -= amount
        print(f"Withdrew {amount:.2f}. New balance: {balance:.2f}")
    except ValueError:
        print("Invalid amount!")

def change_pin():
    global pin
    old_pin = input("Enter current PIN: ").strip()
    if old_pin != pin:
        print("Incorrect PIN!")
        return
    new_pin = input("Enter new PIN: ").strip()
    confirm_pin = input("Confirm new PIN: ").strip()
    if new_pin != confirm_pin:
        print("PINs do not match!")
        return
    if not new_pin.isdigit() or len(new_pin) < 4:
        print("PIN must be at least 4 digits!")
        return
    pin = new_pin
    print("PIN successfully changed.")
def main():
    global pin
    attempts = 3
    while attempts > 0:
        entered_pin = input("Enter your PIN: ").strip()
        if entered_pin == pin:
            break
        attempts -= 1
        print(f"Incorrect PIN. {attempts} attempt(s) left.")
        if attempts == 0:
            print("Too many incorrect attempts. Access denied!")
            return

    while True:
        print("\n\n   ATM Menu    ")
        print("1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Change PIN")
        print("5. Exit")
        choice = input("Enter choice (1-5): ").strip()

        if choice == "1":
            check_balance()
        elif choice == "2":
            deposit()
        elif choice == "3":
            withdraw()
        elif choice == "4":
            change_pin()
        elif choice == "5":
            print("Thank you for using the ATM. Goodbye!")
            break
        else:
            print("Invalid choice, try again.")
if __name__ == "__main__":
    main()
# Out:
# Enter your PIN: 1234
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Change PIN
# 5. Exit
# Enter choice (1-5): 1
# Your current balance is: 0.00
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Change PIN
# 5. Exit
# Enter choice (1-5): 2
# Enter amount to deposit: 1000000
# Deposited 1000000.00. New balance: 1000000.00
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Change PIN
# 5. Exit
# Enter choice (1-5): 3
# Enter amount to withdraw: 50000
# Withdrew 50000.00. New balance: 950000.00
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Change PIN
# 5. Exit
# Enter choice (1-5): 1
# Your current balance is: 950000.00
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Change PIN
# 5. Exit
# Enter choice (1-5): 4
# Enter current PIN: 1234
# Enter new PIN: 67890
# Confirm new PIN: 67890
# PIN successfully changed.
#
#
#    ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# ...
